# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.api import ExponentialSmoothing
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from keras.models import Sequential
from keras.layers import SimpleRNN, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
import math

daily_train = pd.read_csv('../../Datasets\Daily-train.csv')
daily_test = pd.read_csv('../../Datasets\Daily-test.csv')

# %% [markdown]
# __Selecting the Time Series Data for Our Predictions__

# %%
df = daily_train.transpose() # The data we train the model
test = daily_test.transpose() # The last actual values which we try to predict

df = df[0]
df = df.iloc[1:]
df = df.dropna()
new_index = pd.RangeIndex(start=0, stop=len(df))
df.index = new_index

test = test[0]
test = test.iloc[1:]
df = df.reset_index(drop=True)
test = test.reset_index(drop=True)
new_index = pd.RangeIndex(start=len(df), stop=len(df) + len(test))
test.index = new_index

# Connect all dataset train(df) and test data
Series = pd.concat([df, test], axis=0)
Series1 = pd.concat([df, test], axis=1, keys=['Train', 'Test'])

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# __Time Series Decomposition: Additive Seasonal Decomposition__

# %%
decomp = seasonal_decompose(df, model='additive', period=120)
observed = decomp.observed
trend = decomp.trend
seasonal = decomp.seasonal
residual = decomp.resid
data = pd.concat([observed, trend, seasonal, residual], axis=1)
data.columns = ['observed', 'trend', 'seasonal', 'residual']

# Plot the data
fig, axes = plt.subplots(figsize=(14, 8))
data.observed.plot(ax=axes, label='Observed')
data.trend.plot(ax=axes, label='Trend')
axes.legend()
plt.show()

# %%
# Copy the trend component
trend_filled = trend.copy()

# Set the window size for the moving average
window_size = 80

# Apply moving average to fill missing values in the trend component
trend_filled = trend_filled.rolling(window=window_size, min_periods=1, center=True).mean()


# Concatenate the components into a DataFrame
data = pd.concat([observed, trend_filled, seasonal], axis=1)
data.dropna(inplace=True)
data.columns = ['observed', 'trend', 'seasonal']

# Plot the data
fig, axes = plt.subplots(figsize=(14, 8))
data.observed.plot(ax=axes, label='Observed')
data.trend.plot(ax=axes, label='Trend')
axes.legend()
plt.show()

# %% [markdown]
# __Fixed the Null Values in the Trend Component with Additive Holt's Exponential Smoothing__

# %%
# Identify the indices of null values in the trend component
null_indices = trend.isnull()

# Perform exponential smoothing to fill null values in the trend component
model = ExponentialSmoothing(observed[~null_indices], trend='add', seasonal=None)
fitted_model = model.fit()
trend_filled = fitted_model.predict(start=0, end=len(trend)-1)

# Replace the null values in the original trend with the smoothed values
trend[null_indices] = trend_filled[null_indices]

# Concatenate the components into a DataFrame
data = pd.concat([observed, trend, seasonal, residual], axis=1)
data.columns = ['observed', 'trend', 'seasonal', 'residual']


# Plot the data
fig, axes = plt.subplots(figsize=(14, 8))
data.observed.plot(ax=axes, label='Observed')
data.trend.plot(ax=axes, label='Trend')
axes.legend()
plt.show()

# %%
data.isna().sum()
# Out:
# observed      0
# trend         0
# seasonal      0
# residual    120
# dtype: int64

# %% [markdown]
# ## Prepare the Data

# %%
scaler = MinMaxScaler()
scaled_df = scaler.fit_transform(data[['observed', 'trend']])

df_train, df_test = scaled_df[:int(len(scaled_df)*0.8)], scaled_df[int(len(scaled_df)*0.8):]

window_size = 7
step =1

def create_sequences(df, window_size, step):
    X = []
    y = []

    for i in range(window_size, len(df)):
        X.append(df[i-window_size:i, :])  # Include all features in the window
        y.append(df[i, 0])  # Assuming 'Values' column is the target

    X = np.array(X)
    y = np.array(y)
    return X, y

X_train, y_train = create_sequences(df_train, window_size, step)
X_test, y_test = create_sequences(df_test, window_size, step)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((765, 7, 2), (765,), (186, 7, 2), (186,))

# %% [markdown]
# __Create the First Model__

# %%
model = Sequential()
model.add(SimpleRNN(units=64, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=8, activation='relu'))
model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mse')
#callbacks= tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=14)
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 3s 25ms/step - loss: 0.0807 - val_loss: 0.0566
# Epoch 2/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0120 - val_loss: 0.0828
# Epoch 3/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 0.0553
# Epoch 4/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0070 - val_loss: 0.0540
# Epoch 5/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0055 - val_loss: 0.0562
# Epoch 6/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0431
# Epoch 7/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0492
# Epoch 8/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0427
# Epoch 9/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0412
# Epoch 10/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0371
# Epoch 11/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0252
# Epoch 12/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0358
# Epoch 13/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0237
# Epoch 14/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0224
# Epoch 15/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0251
# Epoch 16/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0419
# Epoch 17/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0329
# Epoch 18/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0369
# Epoch 19/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0253
# Epoch 20/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0371
# Epoch 21/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0374
# Epoch 22/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0363
# Epoch 23/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0014 - val_loss: 0.0397
# Epoch 24/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0377
# Epoch 25/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 0.0408
# Epoch 26/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0385
# Epoch 27/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0348
# Epoch 28/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 0.0321
# Epoch 29/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0352
# Epoch 30/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0297
# Epoch 31/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0338
# Epoch 32/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0240
# Epoch 33/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0271
# Epoch 34/100
# 25/25 [==============================] - 0s 5ms/step - loss: 9.6127e-04 - val_loss: 0.0286
# Epoch 35/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0283
# Epoch 36/100
# 25/25 [==============================] - 0s 5ms/step - loss: 8.0908e-04 - val_loss: 0.0316
# Epoch 37/100
# 25/25 [==============================] - 0s 5ms/step - loss: 7.3714e-04 - val_loss: 0.0329
# Epoch 38/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0259
# Epoch 39/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0010 - val_loss: 0.0228
# Epoch 40/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0290
# Epoch 41/100
# 25/25 [==============================] - 0s 5ms/step - loss: 8.0172e-04 - val_loss: 0.0301
# Epoch 42/100
# 25/25 [==============================] - 0s 5ms/step - loss: 8.8104e-04 - val_loss: 0.0231
# Epoch 43/100
# 25/25 [==============================] - 0s 5ms/step - loss: 8.6552e-04 - val_loss: 0.0283
# Epoch 44/100
# 25/25 [==============================] - 0s 5ms/step - loss: 8.9423e-04 - val_loss: 0.0296
# Epoch 45/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0328
# Epoch 46/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0010 - val_loss: 0.0267
# Epoch 47/100
# 25/25 [==============================] - 0s 5ms/step - loss: 6.4089e-04 - val_loss: 0.0273
# Epoch 48/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0280
# Epoch 49/100
# 25/25 [==============================] - 0s 5ms/step - loss: 8.8790e-04 - val_loss: 0.0305
# Epoch 50/100
# 25/25 [==============================] - 0s 5ms/step - loss: 5.5573e-04 - val_loss: 0.0309
# Epoch 51/100
# 25/25 [==============================] - 0s 5ms/step - loss: 5.7632e-04 - val_loss: 0.0250
# Epoch 52/100
# 25/25 [==============================] - 0s 5ms/step - loss: 7.3163e-04 - val_loss: 0.0246
# Epoch 53/100
# 25/25 [==============================] - 0s 5ms/step - loss: 7.0451e-04 - val_loss: 0.0294
# Epoch 54/100
# 25/25 [==============================] - 0s 5ms/step - loss: 6.8465e-04 - val_loss: 0.0243
# Epoch 55/100
# 25/25 [==============================] - 0s 5ms/step - loss: 5.3420e-04 - val_loss: 0.0249
# Epoch 56/100
# 25/25 [==============================] - 0s 5ms/step - loss: 6.6109e-04 - val_loss: 0.0236
# Epoch 57/100
# 25/25 [==============================] - 0s 5ms/step - loss: 6.0518e-04 - val_loss: 0.0216
# Epoch 58/100
# 25/25 [==============================] - 0s 5ms/step - loss: 8.8040e-04 - val_loss: 0.0197
# Epoch 59/100
# 25/25 [==============================] - 0s 5ms/step - loss: 6.1758e-04 - val_loss: 0.0312
# Epoch 60/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0260
# Epoch 61/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0010 - val_loss: 0.0247
# Epoch 62/100
# 25/25 [==============================] - 0s 5ms/step - loss: 5.2923e-04 - val_loss: 0.0248
# Epoch 63/100
# 25/25 [==============================] - 0s 5ms/step - loss: 6.0316e-04 - val_loss: 0.0225
# Epoch 64/100
# 25/25 [==============================] - 0s 6ms/step - loss: 7.2415e-04 - val_loss: 0.0150
# Epoch 65/100
# 25/25 [==============================] - 0s 9ms/step - loss: 6.0726e-04 - val_loss: 0.0221
# Epoch 66/100
# 25/25 [==============================] - 0s 7ms/step - loss: 4.8345e-04 - val_loss: 0.0216
# Epoch 67/100
# 25/25 [==============================] - 0s 7ms/step - loss: 7.6431e-04 - val_loss: 0.0177
# Epoch 68/100
# 25/25 [==============================] - 0s 6ms/step - loss: 6.4669e-04 - val_loss: 0.0231
# Epoch 69/100
# 25/25 [==============================] - 0s 5ms/step - loss: 7.5410e-04 - val_loss: 0.0232
# Epoch 70/100
# 25/25 [==============================] - 0s 5ms/step - loss: 7.1736e-04 - val_loss: 0.0208
# Epoch 71/100
# 25/25 [==============================] - 0s 5ms/step - loss: 5.1318e-04 - val_loss: 0.0202
# Epoch 72/100
# 25/25 [==============================] - 0s 5ms/step - loss: 5.4578e-04 - val_loss: 0.0280
# Epoch 73/100
# 25/25 [==============================] - 0s 6ms/step - loss: 5.3117e-04 - val_loss: 0.0225
# Epoch 74/100
# 25/25 [==============================] - 0s 6ms/step - loss: 4.4269e-04 - val_loss: 0.0212
# Epoch 75/100
# 25/25 [==============================] - 0s 8ms/step - loss: 5.9896e-04 - val_loss: 0.0235
# Epoch 76/100
# 25/25 [==============================] - 0s 9ms/step - loss: 3.7727e-04 - val_loss: 0.0180
# Epoch 77/100
# 25/25 [==============================] - 0s 7ms/step - loss: 5.0826e-04 - val_loss: 0.0171
# Epoch 78/100
# 25/25 [==============================] - 0s 6ms/step - loss: 5.6123e-04 - val_loss: 0.0209
# Epoch 79/100
# 25/25 [==============================] - 0s 10ms/step - loss: 5.3350e-04 - val_loss: 0.0197
# Epoch 80/100
# 25/25 [==============================] - 0s 8ms/step - loss: 5.3854e-04 - val_loss: 0.0227
# Epoch 81/100
# 25/25 [==============================] - 0s 7ms/step - loss: 4.7786e-04 - val_loss: 0.0186
# Epoch 82/100
# 25/25 [==============================] - 0s 6ms/step - loss: 6.8985e-04 - val_loss: 0.0198
# Epoch 83/100
# 25/25 [==============================] - 0s 7ms/step - loss: 4.5723e-04 - val_loss: 0.0223
# Epoch 84/100
# 25/25 [==============================] - 0s 6ms/step - loss: 5.1292e-04 - val_loss: 0.0192
# Epoch 85/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.4051e-04 - val_loss: 0.0176
# Epoch 86/100
# 25/25 [==============================] - 0s 6ms/step - loss: 5.0896e-04 - val_loss: 0.0211
# Epoch 87/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.7717e-04 - val_loss: 0.0269
# Epoch 88/100
# 25/25 [==============================] - 0s 9ms/step - loss: 6.4236e-04 - val_loss: 0.0181
# Epoch 89/100
# 25/25 [==============================] - 0s 8ms/step - loss: 5.1533e-04 - val_loss: 0.0134
# Epoch 90/100
# 25/25 [==============================] - 0s 7ms/step - loss: 4.3958e-04 - val_loss: 0.0198
# Epoch 91/100
# 25/25 [==============================] - 0s 7ms/step - loss: 3.7052e-04 - val_loss: 0.0212
# Epoch 92/100
# 25/25 [==============================] - 0s 6ms/step - loss: 4.9791e-04 - val_loss: 0.0207
# Epoch 93/100
# 25/25 [==============================] - 0s 6ms/step - loss: 4.4240e-04 - val_loss: 0.0160
# Epoch 94/100
# 25/25 [==============================] - 0s 6ms/step - loss: 5.4932e-04 - val_loss: 0.0218
# Epoch 95/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.1795e-04 - val_loss: 0.0179
# Epoch 96/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.7622e-04 - val_loss: 0.0179
# Epoch 97/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.2107e-04 - val_loss: 0.0168
# Epoch 98/100
# 25/25 [==============================] - 0s 5ms/step - loss: 2.7367e-04 - val_loss: 0.0191
# Epoch 99/100
# 25/25 [==============================] - 0s 6ms/step - loss: 4.6068e-04 - val_loss: 0.0200
# Epoch 100/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.2177e-04 - val_loss: 0.0145

# %% [markdown]
# __Create the Second Model__

# %%
# Create the model
model1 = Sequential()
model1.add(LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model1.add(LSTM(64))
model1.add(Dense(32, activation='relu'))
model1.add(Dropout(0.4))
model1.add(Dense(8, activation='relu'))
model1.add(Dense(1, activation='linear'))

model1.compile(loss='mse', optimizer=Adam(learning_rate=0.00001))
#callbacks= tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=14)
history1 = model1.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=250)
# Out:
# Epoch 1/250
# 25/25 [==============================] - 7s 74ms/step - loss: 0.1353 - val_loss: 0.7742
# Epoch 2/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1323 - val_loss: 0.7584
# Epoch 3/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1293 - val_loss: 0.7422
# Epoch 4/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1266 - val_loss: 0.7263
# Epoch 5/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1243 - val_loss: 0.7110
# Epoch 6/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1207 - val_loss: 0.6961
# Epoch 7/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1177 - val_loss: 0.6802
# Epoch 8/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1147 - val_loss: 0.6633
# Epoch 9/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1107 - val_loss: 0.6457
# Epoch 10/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1073 - val_loss: 0.6239
# Epoch 11/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.1039 - val_loss: 0.6035
# Epoch 12/250
# 25/25 [==============================] - 0s 18ms/step - loss: 0.1001 - val_loss: 0.5800
# Epoch 13/250
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0951 - val_loss: 0.5536
# Epoch 14/250
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0909 - val_loss: 0.5282
# Epoch 15/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0863 - val_loss: 0.5007
# Epoch 16/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0806 - val_loss: 0.4703
# Epoch 17/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0774 - val_loss: 0.4412
# Epoch 18/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0712 - val_loss: 0.4121
# Epoch 19/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0680 - val_loss: 0.3835
# Epoch 20/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0626 - val_loss: 0.3545
# Epoch 21/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0579 - val_loss: 0.3266
# Epoch 22/250
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0540 - val_loss: 0.2998
# Epoch 23/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0500 - val_loss: 0.2732
# Epoch 24/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0455 - val_loss: 0.2469
# Epoch 25/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0417 - val_loss: 0.2216
# Epoch 26/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0373 - val_loss: 0.1971
# Epoch 27/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0358 - val_loss: 0.1735
# Epoch 28/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0310 - val_loss: 0.1515
# Epoch 29/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0293 - val_loss: 0.1314
# Epoch 30/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0239 - val_loss: 0.1122
# Epoch 31/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0220 - val_loss: 0.0953
# Epoch 32/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0216 - val_loss: 0.0805
# Epoch 33/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0216 - val_loss: 0.0674
# Epoch 34/250
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0190 - val_loss: 0.0560
# Epoch 35/250
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0176 - val_loss: 0.0461
# Epoch 36/250
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0174 - val_loss: 0.0380
# Epoch 37/250
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0161 - val_loss: 0.0321
# Epoch 38/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0146 - val_loss: 0.0274
# Epoch 39/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0155 - val_loss: 0.0234
# Epoch 40/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0164 - val_loss: 0.0193
# Epoch 41/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0129 - val_loss: 0.0166
# Epoch 42/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0149 - val_loss: 0.0142
# Epoch 43/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0144 - val_loss: 0.0131
# Epoch 44/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0144 - val_loss: 0.0121
# Epoch 45/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0157 - val_loss: 0.0109
# Epoch 46/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0139 - val_loss: 0.0100
# Epoch 47/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0132 - val_loss: 0.0094
# Epoch 48/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0123 - val_loss: 0.0088
# Epoch 49/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0116 - val_loss: 0.0091
# Epoch 50/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0133 - val_loss: 0.0087
# Epoch 51/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0115 - val_loss: 0.0078
# Epoch 52/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0129 - val_loss: 0.0068
# Epoch 53/250
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0127 - val_loss: 0.0062
# Epoch 54/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0112 - val_loss: 0.0058
# Epoch 55/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0118 - val_loss: 0.0060
# Epoch 56/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0126 - val_loss: 0.0049
# Epoch 57/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0121 - val_loss: 0.0041
# Epoch 58/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0124 - val_loss: 0.0033
# Epoch 59/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0107 - val_loss: 0.0035
# Epoch 60/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0113 - val_loss: 0.0031
# Epoch 61/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0113 - val_loss: 0.0029
# Epoch 62/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0103 - val_loss: 0.0029
# Epoch 63/250
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0103 - val_loss: 0.0028
# Epoch 64/250
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0102 - val_loss: 0.0024
# Epoch 65/250
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0121 - val_loss: 0.0023
# Epoch 66/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0096 - val_loss: 0.0026
# Epoch 67/250
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0123 - val_loss: 0.0022
# Epoch 68/250
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0117 - val_loss: 0.0018
# Epoch 69/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0097 - val_loss: 0.0017
# Epoch 70/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0110 - val_loss: 0.0015
# Epoch 71/250
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0093 - val_loss: 0.0018
# Epoch 72/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0106 - val_loss: 0.0016
# Epoch 73/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0102 - val_loss: 0.0015
# Epoch 74/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0099 - val_loss: 0.0014
# Epoch 75/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0105 - val_loss: 0.0012
# Epoch 76/250
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0092 - val_loss: 0.0011
# Epoch 77/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0094 - val_loss: 9.1069e-04
# Epoch 78/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0107 - val_loss: 7.7231e-04
# Epoch 79/250
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0090 - val_loss: 7.8171e-04
# Epoch 80/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0100 - val_loss: 7.5205e-04
# Epoch 81/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0095 - val_loss: 8.4864e-04
# Epoch 82/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0092 - val_loss: 8.8495e-04
# Epoch 83/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0093 - val_loss: 7.9029e-04
# Epoch 84/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 7.7137e-04
# Epoch 85/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0080 - val_loss: 7.8298e-04
# Epoch 86/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0089 - val_loss: 7.9529e-04
# Epoch 87/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0083 - val_loss: 7.9661e-04
# Epoch 88/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0084 - val_loss: 8.1552e-04
# Epoch 89/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0090 - val_loss: 8.2135e-04
# Epoch 90/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0084 - val_loss: 8.2112e-04
# Epoch 91/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0091 - val_loss: 8.5465e-04
# Epoch 92/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0080 - val_loss: 8.7317e-04
# Epoch 93/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0079 - val_loss: 8.7919e-04
# Epoch 94/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0081 - val_loss: 9.6889e-04
# Epoch 95/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 8.8730e-04
# Epoch 96/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0089 - val_loss: 0.0011
# Epoch 97/250
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0081 - val_loss: 9.2508e-04
# Epoch 98/250
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0083 - val_loss: 9.4267e-04
# Epoch 99/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0085 - val_loss: 0.0013
# Epoch 100/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0068 - val_loss: 0.0013
# Epoch 101/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0088 - val_loss: 0.0010
# Epoch 102/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0095 - val_loss: 0.0011
# Epoch 103/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0083 - val_loss: 0.0011
# Epoch 104/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0079 - val_loss: 0.0012
# Epoch 105/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0075 - val_loss: 9.9664e-04
# Epoch 106/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0085 - val_loss: 9.4380e-04
# Epoch 107/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0080 - val_loss: 0.0013
# Epoch 108/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0076 - val_loss: 0.0011
# Epoch 109/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0078 - val_loss: 0.0011
# Epoch 110/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0086 - val_loss: 0.0012
# Epoch 111/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0082 - val_loss: 0.0012
# Epoch 112/250
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0078 - val_loss: 0.0010
# Epoch 113/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0011
# Epoch 114/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0080 - val_loss: 0.0010
# Epoch 115/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0076 - val_loss: 0.0010
# Epoch 116/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0085 - val_loss: 0.0010
# Epoch 117/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0076 - val_loss: 9.9115e-04
# Epoch 118/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0011
# Epoch 119/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0072 - val_loss: 0.0011
# Epoch 120/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0010
# Epoch 121/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0072 - val_loss: 0.0010
# Epoch 122/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0076 - val_loss: 0.0010
# Epoch 123/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0074 - val_loss: 9.8050e-04
# Epoch 124/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0088 - val_loss: 0.0011
# Epoch 125/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0065 - val_loss: 0.0011
# Epoch 126/250
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0069 - val_loss: 0.0012
# Epoch 127/250
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0073 - val_loss: 0.0013
# Epoch 128/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0073 - val_loss: 0.0012
# Epoch 129/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0069 - val_loss: 9.9042e-04
# Epoch 130/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0082 - val_loss: 0.0013
# Epoch 131/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 132/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0070 - val_loss: 0.0011
# Epoch 133/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0074 - val_loss: 0.0013
# Epoch 134/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0072 - val_loss: 0.0011
# Epoch 135/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0076 - val_loss: 0.0010
# Epoch 136/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0070 - val_loss: 0.0011
# Epoch 137/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0076 - val_loss: 0.0010
# Epoch 138/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0077 - val_loss: 0.0011
# Epoch 139/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0011
# Epoch 140/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0064 - val_loss: 0.0011
# Epoch 141/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0066 - val_loss: 0.0011
# Epoch 142/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0010
# Epoch 143/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0011
# Epoch 144/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0063 - val_loss: 9.9076e-04
# Epoch 145/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0012
# Epoch 146/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0064 - val_loss: 0.0010
# Epoch 147/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0076 - val_loss: 0.0010
# Epoch 148/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0012
# Epoch 149/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0071 - val_loss: 0.0011
# Epoch 150/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0067 - val_loss: 0.0013
# Epoch 151/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0058 - val_loss: 0.0016
# Epoch 152/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0071 - val_loss: 0.0010
# Epoch 153/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0078 - val_loss: 0.0010
# Epoch 154/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0064 - val_loss: 9.8629e-04
# Epoch 155/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0067 - val_loss: 0.0011
# Epoch 156/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0063 - val_loss: 9.9615e-04
# Epoch 157/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0061 - val_loss: 9.7790e-04
# Epoch 158/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 9.9853e-04
# Epoch 159/250
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0070 - val_loss: 0.0011
# Epoch 160/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0065 - val_loss: 0.0013
# Epoch 161/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0065 - val_loss: 0.0013
# Epoch 162/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0059 - val_loss: 0.0010
# Epoch 163/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0067 - val_loss: 0.0011
# Epoch 164/250
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0053 - val_loss: 0.0012
# Epoch 165/250
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0062 - val_loss: 9.8235e-04
# Epoch 166/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0062 - val_loss: 0.0010
# Epoch 167/250
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0064 - val_loss: 0.0011
# Epoch 168/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0011
# Epoch 169/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0057 - val_loss: 0.0012
# Epoch 170/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0011
# Epoch 171/250
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0059 - val_loss: 0.0010
# Epoch 172/250
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0072 - val_loss: 0.0011
# Epoch 173/250
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0056 - val_loss: 0.0012
# Epoch 174/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0067 - val_loss: 0.0013
# Epoch 175/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0061 - val_loss: 0.0012
# Epoch 176/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0010
# Epoch 177/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0012
# Epoch 178/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0011
# Epoch 179/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0065 - val_loss: 0.0013
# Epoch 180/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0012
# Epoch 181/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0011
# Epoch 182/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0011
# Epoch 183/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0011
# Epoch 184/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0010
# Epoch 185/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 9.7105e-04
# Epoch 186/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 9.7016e-04
# Epoch 187/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0011
# Epoch 188/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0011
# Epoch 189/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0011
# Epoch 190/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 9.6350e-04
# Epoch 191/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0011
# Epoch 192/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0065 - val_loss: 0.0012
# Epoch 193/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0053 - val_loss: 9.5285e-04
# Epoch 194/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0063 - val_loss: 9.5138e-04
# Epoch 195/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 9.4304e-04
# Epoch 196/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 9.8875e-04
# Epoch 197/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0066 - val_loss: 9.4728e-04
# Epoch 198/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 9.8602e-04
# Epoch 199/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0061 - val_loss: 9.6015e-04
# Epoch 200/250
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0060 - val_loss: 9.5590e-04
# Epoch 201/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0010
# Epoch 202/250
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0060 - val_loss: 0.0010
# Epoch 203/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0055 - val_loss: 9.3673e-04
# Epoch 204/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 9.3292e-04
# Epoch 205/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0061 - val_loss: 9.4285e-04
# Epoch 206/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 9.9009e-04
# Epoch 207/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 9.1570e-04
# Epoch 208/250
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0055 - val_loss: 9.1614e-04
# Epoch 209/250
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0050 - val_loss: 0.0011
# Epoch 210/250
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0057 - val_loss: 9.1669e-04
# Epoch 211/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0052 - val_loss: 9.1508e-04
# Epoch 212/250
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0049 - val_loss: 9.1055e-04
# Epoch 213/250
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0049 - val_loss: 9.5783e-04
# Epoch 214/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 9.1550e-04
# Epoch 215/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 9.6419e-04
# Epoch 216/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 9.5957e-04
# Epoch 217/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0073 - val_loss: 9.2913e-04
# Epoch 218/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0051 - val_loss: 9.3671e-04
# Epoch 219/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 9.3578e-04
# Epoch 220/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0055 - val_loss: 9.0180e-04
# Epoch 221/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 8.9881e-04
# Epoch 222/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 9.3019e-04
# Epoch 223/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0049 - val_loss: 9.1512e-04
# Epoch 224/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0066 - val_loss: 9.5066e-04
# Epoch 225/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 9.5108e-04
# Epoch 226/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0056 - val_loss: 9.3511e-04
# Epoch 227/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 8.9040e-04
# Epoch 228/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0048 - val_loss: 9.9050e-04
# Epoch 229/250
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0060 - val_loss: 8.8841e-04
# Epoch 230/250
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0059 - val_loss: 8.8572e-04
# Epoch 231/250
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0055 - val_loss: 8.8179e-04
# Epoch 232/250
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0052 - val_loss: 0.0010
# Epoch 233/250
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 234/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 9.3860e-04
# Epoch 235/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 9.5589e-04
# Epoch 236/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 9.1864e-04
# Epoch 237/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 9.3691e-04
# Epoch 238/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 9.6824e-04
# Epoch 239/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 8.7268e-04
# Epoch 240/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 8.5498e-04
# Epoch 241/250
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0055 - val_loss: 8.6283e-04
# Epoch 242/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0051 - val_loss: 8.5452e-04
# Epoch 243/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 8.5151e-04
# Epoch 244/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 8.9863e-04
# Epoch 245/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 9.0782e-04
# Epoch 246/250
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 8.9292e-04
# Epoch 247/250
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0052 - val_loss: 9.1176e-04
# Epoch 248/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0052 - val_loss: 0.0011
# Epoch 249/250
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0056 - val_loss: 9.3848e-04
# Epoch 250/250
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0050 - val_loss: 8.8234e-04

# %% [markdown]
# __Comparing Training and Validation Loss: SimpleRNN vs LSTM__

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss)+1)

loss1 = history1.history['loss']
val_loss1 = history1.history['val_loss']
epochs1 = range(1, len(loss1)+1)

fig, ax = plt.subplots(1, 2, figsize=(15, 8))

ax[0].plot(epochs, loss, label='Training Loss')
ax[0].plot(epochs, val_loss, label='Validation Loss')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Training and Validatin loss from SimpleRNN')
ax[0].legend()

ax[1].plot(epochs1, loss1, label='Training Loss')
ax[1].plot(epochs1, val_loss1, label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Training and Validatin loss from LSTM')
ax[1].legend()

plt.subplots_adjust(wspace=0.3)

plt.show()

# %% [markdown]
# __Multivariate Multistep Time Series Forecasting__

# %%
n_features = X_train.shape[2]
num_forecast = 14

def forecasting_with_n_features(model, num_forecast, window_size, n_features):
    # Reshape the last sequence in X_test for forecasting
    X_forecast = np.reshape(X_test[-1], (1, window_size, n_features))

    # Generate the forecasts
    Forecast = []
    for _ in range(num_forecast):
        next_value = model.predict(X_forecast)  # Get the next predicted value
        Forecast.append(next_value)

        # Update X_forecast for the next prediction
        X_forecast = np.roll(X_forecast, -1, axis=1)
        X_forecast[0, -1, 0] = next_value  # Update the last value in the sequence with the predicted value

    Forecast = np.array(Forecast)
    Forecast = Forecast.reshape(-1, 1)  # Reshape to (num_forecast, 1)

    # Perform inverse transformation on the forecasted data
    # Concatenate the Forecast array with a zero-filled array to match the desired shape
    Forecast = np.concatenate((Forecast, np.zeros((num_forecast, n_features-1))), axis=1)

    # Apply the inverse_transform function from the scaler object to the concatenated array
    Forecast = scaler.inverse_transform(Forecast)

    # Select only the first column of the transformed array using [:, 0] indexing
    Forecast = Forecast[:, 0]

   # Print the forecasts
    if num_forecast == len(test):
        print("Forecasts:")
        for i, forecast in enumerate(Forecast):
            if i < 9:
                print(f"Predicted Price {i+1}: {round(float(forecast), 1)}", '   |  The Actual value:', test.iloc[i])
            else:
                print(f"Predicted Price {i+1}: {round(float(forecast), 1)}", '  |  The Actual value:', test.iloc[i])

    return Forecast

# %%
Forc_mod = forecasting_with_n_features(model, len(test), window_size, n_features)
# Out:
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# Forecasts:
# Predicted Price 1: 1859.3    |  The Actual value: 2039.2
# Predicted Price 2: 1848.2    |  The Actual value: 2035.0
# Predicted Price 3: 1824.6    |  The Actual value: 2051.8
# Predicted Price 4: 1798.1    |  The Actual value: 2061.8
# Predicted Price 5: 1791.6    |  The Actual value: 2063.5
# Predicted Price 6: 1774.6    |  The Actual value: 2069.5
# Predicted Price 7: 1754.2    |  The Actual value: 2054.0
# Predicted Price 8: 1737.8    |  The Actual value: 2057.0
# Predicted Price 9: 1727.2    |  The Actual value: 2062.8
# Predicted Price 10: 1717.4   |  The Actual value: 2066.4
# Predicted Price 11: 1709.2   |  The Actual value: 2067.4
# Predicted Price 12: 1702.9   |  The Actual value: 2071.4
# Predicted Price 13: 1695.4   |  The Actual value: 2083.8
# Predicted Price 14: 1688.9   |  The Actual value: 2080.6

# %%
Forc_mod1 = forecasting_with_n_features(model1, len(test), window_size, n_features)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# Forecasts:
# Predicted Price 1: 2044.9    |  The Actual value: 2039.2
# Predicted Price 2: 2046.4    |  The Actual value: 2035.0
# Predicted Price 3: 2048.1    |  The Actual value: 2051.8
# Predicted Price 4: 2051.7    |  The Actual value: 2061.8
# Predicted Price 5: 2054.3    |  The Actual value: 2063.5
# Predicted Price 6: 2058.2    |  The Actual value: 2069.5
# Predicted Price 7: 2061.1    |  The Actual value: 2054.0
# Predicted Price 8: 2063.1    |  The Actual value: 2057.0
# Predicted Price 9: 2064.8    |  The Actual value: 2062.8
# Predicted Price 10: 2066.5   |  The Actual value: 2066.4
# Predicted Price 11: 2068.1   |  The Actual value: 2067.4
# Predicted Price 12: 2069.4   |  The Actual value: 2071.4
# Predicted Price 13: 2070.4   |  The Actual value: 2083.8
# Predicted Price 14: 2071.1   |  The Actual value: 2080.6

# %% [markdown]
# __Visualizing Multistep Forecasting for Our Two Models__

# %%
# SimpleRNN Model
Forc_mod = pd.DataFrame(Forc_mod)
Forc_mod = Forc_mod.reset_index(drop=True)
new_index = pd.RangeIndex(start=len(df), stop= len(df) + len(Forc_mod))
Forc_mod.index = new_index

# LSTM Model
Forc_mod1 = pd.DataFrame(Forc_mod1)
Forc_mod1 = Forc_mod1.reset_index(drop=True)
Forc_mod1.index = new_index

fig, axs = plt.subplots(1, 2, figsize=(22, 9))

# Plotting the SimpleRNN.
axs[0].plot(Forc_mod.tail(100), label='Forecast', color='green')
axs[0].plot(Series1.Train.tail(100), label='Train', color='blue')
axs[0].plot(Series1.Test.tail(100), label='Test', color='orange')
axs[0].set_xlabel('Time')
axs[0].set_ylabel('Price')
axs[0].set_title('SimpleRNN')
axs[0].legend()

# Plotting the LSTM.
axs[1].plot(Forc_mod1.tail(100), label='Forecast', color='green')
axs[1].plot(Series1.Train.tail(100), label='Train', color='blue')
axs[1].plot(Series1.Test.tail(100), label='Test', color='orange')
axs[1].set_xlabel('Time')
axs[1].set_ylabel('Price')
axs[1].set_title('LSTM')
axs[1].legend()

plt.subplots_adjust(wspace=0.3)
plt.show()

# %% [markdown]
# __Conclusion:__<br><br>
# **When we compared two models for predicting time series data, the LSTM model stood out as the better option. It performed more accurately and could generalize well, avoiding the problem of overfitting seen in the SimpleRNN model. While the LSTM model isn't perfect and might still have some small errors, it's a strong choice for time series forecasting tasks.**
